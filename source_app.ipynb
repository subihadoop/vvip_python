# %%
import subprocess
from subprocess import Popen
import re
import sys
import pexpect
import string
from string import strip
import Vars
import sender
import logging
import time
import csv
import teradata
import pyodbc
import socket
import traceback
import logging
import stat
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-11-d73f5d26fa91> in <module>
#       6
#       7 import string
# ----> 8 from string import strip
#       9 import Vars
#      10 import sender
#
# ImportError: cannot import name 'strip' from 'string' (/home/subi/anaconda3/lib/python3.7/string.py)

# %%
def get_gg_info app,source):
host_nme%3socket.gethostbyaddr(socket.gethostname() )

if host_name == ´yxkid-pdvas001. Emig.com ':
env= 'dev'
else:
if host nme ==
env= prod
-else:9
Vxpip-pdwas@01. tmig.com:9
message= Invaild host name process is teminati
print (message)
sys.stdout.flush()
sys.exit(1)

# %%
try:9
template= Vors. + app +tomptate '9
TEMPLATE=eval(template)9
print (TEMPLATE)9
except Exception as exception:9
message="ERROR: Vors."+ app
str(traceback. format_exc())9
print (message)
sys.stdout. flush()9
sys.exit (1)9
temptate assignment faited. ".+ str(exception) + \n+5
try:
sql_select open(TEMPLATE + ODSAAS_source_appticati on_info_setect', 'r')I
sqlFile = sql_select.read()9
sql_select.close()9
print(sqlFile)I
except Exception as exception:9
message= 'ERROR: Coutd not open ODSAAS_sOurce_apptication_info_setect templote file
%3D
%3D
-+ str(e
.+.+.str(traceback. format_exc())9
print (message)9
sys.stdout. flush()9
sys.exit(1)

# %%
try:
template= Vors. + app +tomptate '9
TEMPLATE=eval(template)9
print (TEMPLATE)9
except Exception as exception:9
message="ERROR: Vors."+ app
str(traceback. format_exc())9
print (message)
sys.stdout. flush()9
sys.exit (1)9
temptate assignment faited. ".+ str(exception) + \n+5
try:
sql_select open(TEMPLATE + ODSAAS_source_appticati on_info_setect', 'r')I
sqlFile = sql_select.read()9
sql_select.close()9
print(sqlFile)I
except Exception as exception:9
message= 'ERROR: Coutd not open ODSAAS_sOurce_apptication_info_setect templote file
%3D
%3D
-+ str(e.+.+.str(traceback. format_exc())
print (message)9
sys.stdout. flush()9
sys.exit(1)

# %%
if (source =
stdanduk ) or (source
source filter="DETECTION SOURCE ENV NAME="+"batchwyk ) or (source
'pidviduk ): 9
tsource+ " *
elif (source
source
elif (source
"batchkuk ):
filter="DETECTION SOURCE ENV NAME Like +(%BATCHWVK% ") OR DETECT ION
"batchduk ):9
source filter="DETECTION SOURCE ENV NAME=" +
'of e2 ebvk ) or (source
source filter="NONPROD SOURCE ENV NAME="+-" " + source+
+ source +" *
elif (source
Riguobuk ):1
elif source == 'prodvk:
source
filter="PROD SOUR CE ENV NAME="+ " ** -+ source +" g
elif (app== 'fgp' or source == - TOASTUSER
source filter="DETECTION SOURCE ENV NAME Like +
elif ((source
source_filter="(DETECTION_SOUR CE_ENV_NAME tike + (%0DS_PM_CL_CLAIMCENTER DEV
elif (source
source filter="DETECTION_SOURCE_ENV_NAME tike +(%PM CL CONTACT CENTER% ) OR
elif source ==
or source ==- PISLSCMP OLTP ):
# %TOASTUSER%) OR DETECT ION
== 'ods_pm_ct_ctoimcenter_devi ´) or (source == 'pm_ct_ctaimcenter
pm cl_contoctcenter or source ==
pm_ct_contactcenter_dev '):9
source filter="PROD_SOUR CE_ENV_NAME is nutt"
else:9
"message= 'ERROR: Incorrect SOURCE entered. The Process was teminated. "
"print (message)

# %%
try:
SQLFILE=eval(sqlFile)
print SQLFILE
except Exception as exception:
message= 'ERROR: SOLFZLE evol foited -
print (message)
sys.stdout.flush()
sys.exit(1)
+ str(exception) + n+ str(t
pyodbc.pooling = False
try:9
pyodbc.connect(DRIVER="+ DRIVER +- '; ''+ 'DBOVAME='+DBCNAME +
conn=
except Exception as exception:
MesSaoP= 'FRRCOR -
ronn = nchatnnnert -fnited +-striexcention)+ In

# %%
try:
"conn= "pyodbc.connect( 'DRIVER='+ DRIVER +'; '+· 'DBONAME=+DBCNAME + '; "9
UID-+ UID +;+ PWD="+PWD +
except Exception as exc eption:
message= 'ERROR: Conn= pyodbc.connect- faited + str(exception) +\n+'str(traceback.format_exc())+ 'QUIETMODE=YES;Qutoconnit=True')
print (message) 
sys. stdout. flush()
sys.exit(1)

try:5
cursor = Conn.cursor(09
except Exception as exception:9
message= "ERROR: cursor= conn.cursor() failed '+ str(exception) +\n'+ str(traceback. format_exc())S
print (message)
sys.stdout.flush()9
sys.exit(1)9
sql_returned False
try:
cursor.execute(SQLFILE)
print(SQLFILE)
except Exception as exception:
message= 'ERROR: cursor. execute
print (message) 
sys.stdout.flush()
sys.exit (1)
+ SQLFILE +
+ str(exception) + n+str(traceback.format_exc())!

# %%
try:
cursor. execute(SQLFILE)
print(SQLFILE)S
except Exception as exception:
message- "ERROR: cursor.execute + SQLFILE +  str(exception) + In+ str(traceback.format_exc())"
print (message)5
sys.stdout.flush()
sys.exit(1)

try:
app_info = cursor.fetchone()
except Exception as exception:
message= "ERROR: cursor.fetchone()++str(exception) +In+ str(traceback.format_exc())"
print (message)
sys.stdout. flush()
sys.exit (1)

if cursor.rowcount=0:
message= 'ERAOR: SELECT FROM PM_EDW GG META D.ODSAAS_SOUR CE APPLICATION -Did Not return any thing. The Process'
print (message)
sys.stdout.flush()
return False
heading="Get source apptication_info environment variables Failed, there was no Source Application Data returm
sender.send_email(subject-heading, body text=message) 
sys.exit(1).results = {}
gg_project= [S***actual gg_replicat_proj= [ 09 actual_gg_extract_proj=[]]

# %%
while app_info is not None:
gg_project.append(app_info[@]);
actual_gg_replicat proj.append(app_info[ 20]);
actual_gg_extract_proj.append(app_info[18]);
results={"gg_project:gg_project,
"dev NF :app_info[1],
"test NF':app_info[1],
"0q_MF':app_info[2],
"prod NF:app_info[2],
"dev db2_extract :app_info[3],
"dev_d2_pump':app_info[4],
dev fcp_extract :app_info[3],
dev_fcp_pump':app_info[4],
'dev_cngaws extract':app_info[3],
'dev_cngans pump :app_info[4],
dev cng extract':app_info[3],
dev_cng_pump':app_info[4],
dev_mi dtier :app_info[5],
dev dvos':apP_info[6],
test 2_extract':app_info[7],
'test b2_pump':app_info[ 8],
'test fcp_extract':app info[7],
'test fcp_pump´:app_info[8],
'test cng_extract':app_info[7],
'test cng pump':app_info[8],
'test_cngaws extract':app_info[7],
'test cngNs pump':app_info[8],"

# %%
try:
app info cursor.fetchone()
except Exception as exception:
message 'ERROR: cursor.fetchone()
print message
sys. stdout. flush()9
sys. exit (1)9
-no ravs returned. +'str(exception) + \n+'str(traceback, format_exc
return results
lef main(argv):
try:9
app=sys.argv[1].translate(None, "[], ")9
app-Dapp.lower()3
except Exception as exception:9
message="ERRCR: QoD-sys.argv[1] assi gnment failed."+str(exception) + \n + str(traceback. format_exc())9
print (message)9
sys.stdout. flush()9
sys.exit (1)9
try:9
source-sys.argv[2].translate(None, "[], *)I
source-source. lower()9
except Exception as exception:9
message="ERROR: Source-sys.argv[2] assi grment faited."+ str(exception) + In'+ str(traceback. format_exc()
print (message)9
sys.stdout.flush()9
sys.exit(1)9
try:
app info cursor.fetchone()
except Exception as exception:
message 'ERROR: cursor.fetchone()
print message
sys. stdout. flush()9
sys. exit (1)9
-no ravs returned. +'str(exception) + \n+'str(traceback, format_exc
return results
lef main(argv):
try:9
app=sys.argv[1].translate(None, "[], ")9
app-Dapp.lower()3
except Exception as exception:9
message="ERRCR: QoD-sys.argv[1] assi gnment failed."+str(exception) + \n + str(traceback. format_exc())9
print (message)9
sys.stdout. flush()9
sys.exit (1)9
try:9
source-sys.argv[2].translate(None, "[], *)I
source-source. lower()9
except Exception as exception:9
message="ERROR: Source-sys.argv[2] assi grment faited."+ str(exception) + In'+ str(traceback. format_exc()
print (message)9
sys.stdout.flush()9
sys.exit(1)9
